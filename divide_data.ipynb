# %% [markdown]
# # Predicting Viral Host from Codon Usage Bias
#
# ### Kathleen Hablutzel
# ### BIO 334/335 Bioinformatics Final Project
# Run this notebook to separate the generated data into full and biased genome datasets.

# %%
import pandas as pd

import fasta_parser as fp

# %%
fp.clean_working_csv()

# %%
# load data
bias_pd = pd.read_csv("data/working_clean.csv")
bias_pd.drop_duplicates(inplace=True)
bias_pd.shape
# Out:
# (22082, 73)

# %%
bias_pd.head()
# Out:
#         UUU       UUC       UUA       UUG       CUU       CUC       CUA  \
# 0  0.457776  0.542224  0.073146  0.136493  0.138130  0.190055  0.078648
# 1  0.357377  0.642623  0.035458  0.104243  0.099131  0.213422  0.065184
# 2  0.474425  0.525575  0.085792  0.133677  0.136818  0.189876  0.069925
# 3  0.365337  0.634663  0.050157  0.098445  0.096961  0.220268  0.049994
# 4  0.475298  0.524702  0.088171  0.135714  0.139210  0.191816  0.068511
#
#         CUG       AUU       AUC  ...       GGG  BiasedRegionsOnly  \
# 0  0.383528  0.354512  0.476869  ...  0.236004               full
# 1  0.482563  0.277330  0.614248  ...  0.251400             biased
# 2  0.383912  0.363281  0.459382  ...  0.251075               full
# 3  0.484176  0.278849  0.594489  ...  0.282885             biased
# 4  0.376578  0.366103  0.452923  ...  0.247990               full
#
#                    AccessionNum      SeqLen  BiasedSeqLen  PropBiasedRegions  \
# 0    GCF_903992535.2_mArvAmp1.2         NaN      77272509                NaN
# 1    GCF_903992535.2_mArvAmp1.2  77272509.0      26243760             0.3396
# 2     GCF_000493695.1_BalAcu1.0         NaN      69532407                NaN
# 3     GCF_000493695.1_BalAcu1.0  69532407.0      30961362             0.4453
# 4  GCF_000754665.1_Bison_UMD1.0         NaN      62252778                NaN
#
#           Nc   BiasedNc                     Species                 Taxon
# 0        NaN  54.457136          Arvicola_amphibius  vertebrate_mammalian
# 1  54.457136  49.593948          Arvicola_amphibius  vertebrate_mammalian
# 2        NaN  54.651624  Balaenoptera_acutorostrata  vertebrate_mammalian
# 3  54.651624  49.077540  Balaenoptera_acutorostrata  vertebrate_mammalian
# 4        NaN  54.839233                 Bison_bison  vertebrate_mammalian
#
# [5 rows x 73 columns]

# %%
# keep full genomes
bias_pd_full = bias_pd[(bias_pd["BiasedRegionsOnly"] == "full") & (bias_pd["BiasedSeqLen"] > 0)]
bias_pd_full = bias_pd_full.drop(columns=["BiasedRegionsOnly", "SeqLen", "PropBiasedRegions", "Nc"])
bias_pd_full = bias_pd_full.rename(columns={"BiasedSeqLen": "SeqLen", "BiasedNc": "Nc"})
bias_pd_full.shape
# Out:
# (10916, 69)

# %%
bias_pd_full.head()
# Out:
#         UUU       UUC       UUA       UUG       CUU       CUC       CUA  \
# 0  0.457776  0.542224  0.073146  0.136493  0.138130  0.190055  0.078648
# 2  0.474425  0.525575  0.085792  0.133677  0.136818  0.189876  0.069925
# 4  0.475298  0.524702  0.088171  0.135714  0.139210  0.191816  0.068511
# 6  0.453638  0.546362  0.078937  0.127617  0.129814  0.198149  0.064855
# 8  0.449071  0.550929  0.077686  0.128257  0.129594  0.197832  0.066708
#
#         CUG       AUU       AUC  ...       AGG       GGU       GGC       GGA  \
# 0  0.383528  0.354512  0.476869  ...  0.219182  0.180696  0.317858  0.265441
# 2  0.383912  0.363281  0.459382  ...  0.219056  0.164273  0.325674  0.258978
# 4  0.376578  0.366103  0.452923  ...  0.218796  0.168386  0.318368  0.265256
# 6  0.400627  0.351219  0.479417  ...  0.211618  0.159878  0.338769  0.247034
# 8  0.399924  0.351122  0.482238  ...  0.205152  0.157745  0.345172  0.241409
#
#         GGG                     AccessionNum    SeqLen         Nc  \
# 0  0.236004       GCF_903992535.2_mArvAmp1.2  77272509  54.457136
# 2  0.251075        GCF_000493695.1_BalAcu1.0  69532407  54.651624
# 4  0.247990     GCF_000754665.1_Bison_UMD1.0  62252778  54.839233
# 6  0.254319  GCF_000247795.1_Bos_indicus_1.0  64918074  53.953278
# 8  0.255674      GCF_002288905.1_ASM228890v2  67099479  53.983387
#
#                       Species                 Taxon
# 0          Arvicola_amphibius  vertebrate_mammalian
# 2  Balaenoptera_acutorostrata  vertebrate_mammalian
# 4                 Bison_bison  vertebrate_mammalian
# 6                 Bos_indicus  vertebrate_mammalian
# 8              Enhydra_lutris  vertebrate_mammalian
#
# [5 rows x 69 columns]

# %%
bias_pd_full.to_csv("datasets/cub_full_genome.csv", index=False)

# %%
test = pd.read_csv("datasets/cub_full_genome.csv")
test.head()
# Out:
#         UUU       UUC       UUA       UUG       CUU       CUC       CUA  \
# 0  0.457776  0.542224  0.073146  0.136493  0.138130  0.190055  0.078648
# 1  0.474425  0.525575  0.085792  0.133677  0.136818  0.189876  0.069925
# 2  0.475298  0.524702  0.088171  0.135714  0.139210  0.191816  0.068511
# 3  0.453638  0.546362  0.078937  0.127617  0.129814  0.198149  0.064855
# 4  0.449071  0.550929  0.077686  0.128257  0.129594  0.197832  0.066708
#
#         CUG       AUU       AUC  ...       AGG       GGU       GGC       GGA  \
# 0  0.383528  0.354512  0.476869  ...  0.219182  0.180696  0.317858  0.265441
# 1  0.383912  0.363281  0.459382  ...  0.219056  0.164273  0.325674  0.258978
# 2  0.376578  0.366103  0.452923  ...  0.218796  0.168386  0.318368  0.265256
# 3  0.400627  0.351219  0.479417  ...  0.211618  0.159878  0.338769  0.247034
# 4  0.399924  0.351122  0.482238  ...  0.205152  0.157745  0.345172  0.241409
#
#         GGG                     AccessionNum    SeqLen         Nc  \
# 0  0.236004       GCF_903992535.2_mArvAmp1.2  77272509  54.457136
# 1  0.251075        GCF_000493695.1_BalAcu1.0  69532407  54.651624
# 2  0.247990     GCF_000754665.1_Bison_UMD1.0  62252778  54.839233
# 3  0.254319  GCF_000247795.1_Bos_indicus_1.0  64918074  53.953278
# 4  0.255674      GCF_002288905.1_ASM228890v2  67099479  53.983387
#
#                       Species                 Taxon
# 0          Arvicola_amphibius  vertebrate_mammalian
# 1  Balaenoptera_acutorostrata  vertebrate_mammalian
# 2                 Bison_bison  vertebrate_mammalian
# 3                 Bos_indicus  vertebrate_mammalian
# 4              Enhydra_lutris  vertebrate_mammalian
#
# [5 rows x 69 columns]

# %%
test.shape
# Out:
# (10916, 69)

# %%
# just keep genomes using biased regions
bias_pd_biased = bias_pd[(bias_pd["BiasedRegionsOnly"] == "biased") & (bias_pd["BiasedSeqLen"] > 0)]
bias_pd_biased = bias_pd_biased.drop(columns=["BiasedRegionsOnly"])
bias_pd_biased.shape
# Out:
# (8308, 72)

# %%
bias_pd_biased.head()
# Out:
#         UUU       UUC       UUA       UUG       CUU       CUC       CUA  \
# 1  0.357377  0.642623  0.035458  0.104243  0.099131  0.213422  0.065184
# 3  0.365337  0.634663  0.050157  0.098445  0.096961  0.220268  0.049994
# 5  0.371288  0.628712  0.054070  0.102735  0.100069  0.220455  0.050968
# 7  0.348407  0.651593  0.044989  0.095981  0.091464  0.225333  0.047891
# 9  0.339304  0.660696  0.041498  0.094636  0.088775  0.225838  0.048453
#
#         CUG       AUU       AUC  ...       GGA       GGG  \
# 1  0.482563  0.277330  0.614248  ...  0.200728  0.251400
# 3  0.484176  0.278849  0.594489  ...  0.188971  0.282885
# 5  0.471703  0.288741  0.580296  ...  0.196635  0.278049
# 7  0.494342  0.273083  0.609025  ...  0.182954  0.282460
# 9  0.500799  0.266361  0.621156  ...  0.172288  0.287098
#
#                       AccessionNum      SeqLen  BiasedSeqLen  \
# 1       GCF_903992535.2_mArvAmp1.2  77272509.0      26243760
# 3        GCF_000493695.1_BalAcu1.0  69532407.0      30961362
# 5     GCF_000754665.1_Bison_UMD1.0  62252778.0      26328582
# 7  GCF_000247795.1_Bos_indicus_1.0  64918074.0      31421865
# 9      GCF_002288905.1_ASM228890v2  67099479.0      32735730
#
#    PropBiasedRegions         Nc   BiasedNc                     Species  \
# 1             0.3396  54.457136  49.593948          Arvicola_amphibius
# 3             0.4453  54.651624  49.077540  Balaenoptera_acutorostrata
# 5             0.4229  54.839233  49.899251                 Bison_bison
# 7             0.4840  53.953278  48.318396                 Bos_indicus
# 9             0.4879  53.983387  47.681397              Enhydra_lutris
#
#                   Taxon
# 1  vertebrate_mammalian
# 3  vertebrate_mammalian
# 5  vertebrate_mammalian
# 7  vertebrate_mammalian
# 9  vertebrate_mammalian
#
# [5 rows x 72 columns]

# %%
bias_pd_biased.to_csv("datasets/cub_biased_genome.csv", index=False)

# %%
test2 = pd.read_csv("datasets/cub_biased_genome.csv")
test2.head()
# Out:
#         UUU       UUC       UUA       UUG       CUU       CUC       CUA  \
# 0  0.357377  0.642623  0.035458  0.104243  0.099131  0.213422  0.065184
# 1  0.365337  0.634663  0.050157  0.098445  0.096961  0.220268  0.049994
# 2  0.371288  0.628712  0.054070  0.102735  0.100069  0.220455  0.050968
# 3  0.348407  0.651593  0.044989  0.095981  0.091464  0.225333  0.047891
# 4  0.339304  0.660696  0.041498  0.094636  0.088775  0.225838  0.048453
#
#         CUG       AUU       AUC  ...       GGA       GGG  \
# 0  0.482563  0.277330  0.614248  ...  0.200728  0.251400
# 1  0.484176  0.278849  0.594489  ...  0.188971  0.282885
# 2  0.471703  0.288741  0.580296  ...  0.196635  0.278049
# 3  0.494342  0.273083  0.609025  ...  0.182954  0.282460
# 4  0.500799  0.266361  0.621156  ...  0.172288  0.287098
#
#                       AccessionNum      SeqLen  BiasedSeqLen  \
# 0       GCF_903992535.2_mArvAmp1.2  77272509.0      26243760
# 1        GCF_000493695.1_BalAcu1.0  69532407.0      30961362
# 2     GCF_000754665.1_Bison_UMD1.0  62252778.0      26328582
# 3  GCF_000247795.1_Bos_indicus_1.0  64918074.0      31421865
# 4      GCF_002288905.1_ASM228890v2  67099479.0      32735730
#
#    PropBiasedRegions         Nc   BiasedNc                     Species  \
# 0             0.3396  54.457136  49.593948          Arvicola_amphibius
# 1             0.4453  54.651624  49.077540  Balaenoptera_acutorostrata
# 2             0.4229  54.839233  49.899251                 Bison_bison
# 3             0.4840  53.953278  48.318396                 Bos_indicus
# 4             0.4879  53.983387  47.681397              Enhydra_lutris
#
#                   Taxon
# 0  vertebrate_mammalian
# 1  vertebrate_mammalian
# 2  vertebrate_mammalian
# 3  vertebrate_mammalian
# 4  vertebrate_mammalian
#
# [5 rows x 72 columns]

# %%
test2.shape
# Out:
# (8308, 72)
